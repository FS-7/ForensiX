# %%
import face_recognition as fr
import os
import numpy as np

# %%
faces_enc = []
faces_loc = []
faces = []
for i in os.listdir(path="./data/other"):
    data = fr.load_image_file("./data/other/" + i)
    for a in fr.face_locations(data):
        faces.append((a, fr.face_encodings(face_image=data, known_face_locations=[a])))

# %%
#print(faces)
for i, j in enumerate(faces, 1):
    print(i, j[1])

# %%
for row in faces:
    print(row[1])
# Out:
# [array([-0.11497737, -0.00712863,  0.071793  , -0.13024591, -0.10130819,
#        -0.10371769, -0.04031582, -0.13636227,  0.21418089, -0.25201434,
#         0.12434079, -0.09511682, -0.17383702,  0.04892532, -0.09433693,
#         0.12722073, -0.1319429 , -0.24050355, -0.06478389, -0.05560005,
#         0.05642695, -0.00961661, -0.0275713 ,  0.13015997, -0.17415011,
#        -0.32934129, -0.08961175, -0.01604154,  0.01427789, -0.03709763,
#         0.03202538,  0.15965618, -0.25174966,  0.02120976, -0.00903197,
#         0.16166718,  0.07448135, -0.07867632,  0.14312556, -0.03274791,
#        -0.31098858, -0.01846114,  0.07592889,  0.19875713,  0.12460074,
#        -0.01268178,  0.0215753 , -0.12375542,  0.08044084, -0.26586595,
#         0.10720222,  0.14665829,  0.06617711, -0.01931279,  0.12026989,
#        -0.16721778,  0.03932173,  0.08335213, -0.16763754,  0.06287741,
#         0.090707  , -0.03823449, -0.01474019, -0.09743437,  0.15655822,
# ...

# %%
similarity = []

for i, j in enumerate(faces, 1):
    print(fr.compare_faces(faces[], j), end="\t")
    print(j)
        #if(fr.compare_faces([j], i) == np.True_):
            #print(faces_loc[x])
    print("\n")
