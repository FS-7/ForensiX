# %% [markdown]
# adb pull "/data/data/com.google.android.apps.maps/databases/gmm_storage.db" > gps.db

# %% [markdown]
# adb pull "/sdcard/CallRecordings" "OUTPUT/CallRecordings"
# adb pull "/sdcard/DCIM" "OUTPUT/DCIM"
# adb pull "/sdcard/" "OUTPUT/"
